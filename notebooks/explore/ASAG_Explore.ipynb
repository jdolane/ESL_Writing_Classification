# %% [markdown]
# # Explore the ASAG dataset
# This notebook is to explore the ASAG dataset.

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/ASAG_balanced.csv')
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   L1             100 non-null    object
#  1   question       100 non-null    object
#  2   answer         100 non-null    object
#  3   level          100 non-null    int64
#  4   question_type  100 non-null    object
#  5   num_sentences  100 non-null    float64
#  6   is_augmented   100 non-null    int64
#  7   length         100 non-null    int64
#  8   dataset        100 non-null    object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 7.2+ KB

# %%
df.level.value_counts()
# Out:
# level
# 2    25
# 3    25
# 4    25
# 5    25
# Name: count, dtype: int64

# %%
df.L1.value_counts()
# Out:
# L1
# French     94
# German      2
# Arabic      1
# Dutch       1
# Swahili     1
# Russian     1
# Name: count, dtype: int64

# %%
# Plotting
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='level', hue='L1')
plt.title('Distribution of L1 by Level')
plt.xlabel('Level')
plt.ylabel('Count')
plt.legend(title='L1', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(7, 5))

# Plotting length by level
sns.boxplot(data=df, x='level', y='length')
plt.title('Length Distribution by Level')
plt.xlabel('Level')
plt.ylabel('Length')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))

# Plotting length by level
sns.boxplot(data=df, x='level', y='num_sentences')
plt.title('Number of sentences by Level')
plt.xlabel('Level')
plt.ylabel('Number of sentences')

plt.tight_layout()
plt.show()

# %%
# Plotting
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='level', hue='is_augmented')
plt.title('Distribution of Augmented Data by Level')
plt.xlabel('Level')
plt.ylabel('Count')
plt.legend(title='Augmented Data', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
