# %% [markdown]
# # Explore all of the data
# This notebook is to explore the entire combined dataset.

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pelic = pd.read_csv('../data/PELIC_balanced.csv').drop(['Unnamed: 0'], axis=1)
asag = pd.read_csv('../data/ASAG_balanced.csv').drop(['Unnamed: 0'], axis=1)

# %%
df = pd.concat([pelic, asag]).reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   level          892 non-null    int64
#  1   L1             892 non-null    object
#  2   question_type  892 non-null    object
#  3   question       892 non-null    object
#  4   answer         892 non-null    object
#  5   num_sentences  892 non-null    float64
#  6   is_augmented   892 non-null    int64
#  7   dataset        892 non-null    object
#  8   length         892 non-null    int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 62.8+ KB

# %%
df.level.value_counts()
# Out:
# level
# 2    223
# 3    223
# 4    223
# 5    223
# Name: count, dtype: int64

# %%
# Plotting
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='level', hue='L1')
plt.title('Distribution of L1 by Level')
plt.xlabel('Level')
plt.ylabel('Count')
plt.legend(title='L1', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(7, 5))

# Plotting length by level
sns.boxplot(data=df, x='level', y='length')
plt.title('Length Distribution by Level')
plt.xlabel('Level')
plt.ylabel('Length')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))

# Plotting length by level
sns.boxplot(data=df, x='level', y='num_sentences')
plt.title('Number of sentences by Level')
plt.xlabel('Level')
plt.ylabel('Number of sentences')

plt.tight_layout()
plt.show()

# %%
# Plotting
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='level', hue='is_augmented')
plt.title('Distribution of Augmented Data by Level')
plt.xlabel('Level')
plt.ylabel('Count')
plt.legend(title='Augmented Data', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
